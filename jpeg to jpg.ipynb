# %%
from google.colab import drive
drive.mount("/content/drive")

import os
os.chdir('/content/drive/MyDrive/JPG cv2 PDF')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import os

# 設定資料夾路徑
input_dir = "黒ギャルVS風紀委員｜黑肉辣妹VS風紀股長1"   # 修改成你的路徑
output_dir = os.path.join(input_dir, "jpeg_to_jpg")

# 建立輸出資料夾（如果不存在）
os.makedirs(output_dir, exist_ok=True)

# 逐一讀取檔案
for filename in os.listdir(input_dir):
    if filename.lower().endswith(".jpeg"):
        file_path = os.path.join(input_dir, filename)

        # 開啟圖片
        with Image.open(file_path) as img:
            # 去掉 .jpeg 副檔名，改成 .jpg
            new_filename = os.path.splitext(filename)[0] + ".jpg"
            new_path = os.path.join(output_dir, new_filename)

            # 存成 jpg 格式
            img.convert("RGB").save(new_path, "JPEG")

print("所有 .jpeg 已轉成 .jpg 並存到 jpeg_to_jpg 資料夾。")
# Out:
# 所有 .jpeg 已轉成 .jpg 並存到 jpeg_to_jpg 資料夾。
